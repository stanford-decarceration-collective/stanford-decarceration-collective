# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data cleaning</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#TODOs" data-toc-modified-id="TODOs-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>TODOs</a></span></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modeling</a></span></li><li><span><a href="#Eligible-population-stats" data-toc-modified-id="Eligible-population-stats-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Eligible population stats</a></span></li></ul></div>

# %% [markdown]
# This notebook is from Fall 2022.
# It uses the court data we scraped in October 2021 to model cannabis policy in VA. Note that this is so old I had to change a couple things to get it to work again, so probably worth cross referencing against other more recent policies that use the same dataset and it might warrant some preprocessing updates.

# %%
import os
import sys
sys.path.insert(0, os.path.relpath('../')) 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from super_simulation.super_simulation_factory import SuperSimulationFactory
from transition_table import TransitionTable
from shell_compartment import ShellCompartment
from spark_policy import SparkPolicy
from utils.spark_bq_utils import upload_spark_model_inputs
import pandas as pd
from functools import partial

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Data cleaning
# Tip: you'll probably want to save the preprocessed file to a csv the first time you run this for a new policy and then import that csv from then on out to save time. To do so, uncomment the `df.to_csv()` line at the bottom of
# this section, then after you run it move that file to `recidiviz-staging>recidiviz>calculator>modeling>population_projection>state>VA>VA_data`. From then on, you can skip everything in the data cleaning section and just run the file import commented out at the end of the section.

# %%
crime_types = [
    'CONSPIRACY', 'DRUG_POSSESSION', 'DRUG_SALE', "DRUG_OTHER", "KIDNAPPING", "MANSLAUGHTER", "LARCENY", "WEAPON",
    "ASSAULT", "ROBBERY", "BURGLARY", "DWI", "RAPE", "SEX_OFFENSE", "ARSON", 'FIRST_DEGREE_MURDER',
    'SECOND_DEGREE_MURDER', 'OTHER_MURDER', 'CAPITAL_MURDER'
]

LOS_BY_CRIME = {
    'CONSPIRACY': 0.899,
    'DRUG_POSSESSION': 0.897,
    'DRUG_SALE': 0.902,
    'DRUG_OTHER': 0.901,
    'KIDNAPPING': 0.913,
    'MANSLAUGHTER': 0.916,
    'LARCENY': 0.907,
    'WEAPON': 0.905,
    'ASSAULT': 0.912,
    'ROBBERY': 0.920,
    'BURGLARY': 0.917,
    'DWI': 0.893,
    'RAPE': 0.906,
    'SEX_OFFENSE': 0.90,
    'ARSON': 0.914,
    'FIRST_DEGREE_MURDER': 0.907,
    'SECOND_DEGREE_MURDER': 0.914,
    'OTHER_MURDER': 0.908,
    'CAPITAL_MURDER': 0.898
}

# %%
sdc_data = pd.concat([
    pd.read_csv(
        f'../state/VA/VA_data/VA_circuit_data/circuit_data_{i}.csv',
        index_col=0
    ) for i in range(8)
])
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\110041657.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(

# %%
sdc_data
# Out:
#                           Address         Amended Charge Amended Charge Type  \
# 0           LYNCHBURG[.] VA 24506                    NaN                 NaN
# 1             ROANOKE[.] VA 24017                    NaN                 NaN
# 2        WILLIAMSBURG[.] VA 23188                    NaN                 NaN
# 3          WOODBRIDGE[.] VA 22191                    NaN                 NaN
# 4            VIRGINIA BEACH[.] VA                    NaN                 NaN
# ...                           ...                    ...                 ...
# 1071603   PORT ORANGE[.] FL 32129                    NaN                 NaN
# 1071604    CHESAPEAKE[.] VA 23323                    NaN                 NaN
# 1071605         CITY UNKNOWN[.]VA                    NaN                 NaN
# 1071606    POMPANO BEACH FL 33060     IMPROPER EQUIPMENT         Misdemeanor
# 1071607     CHANTILLY[.] VA 20152  SP 20+ MPH OVER LIMIT          Infraction
#
#         Amended Code Section Arrest Date                            Charge  \
# 0                        NaN         NaN    RECKLESS DRIVING (SP 95/65 MR)
# 1                        NaN  12/05/2012  DRIVING WHILE INTOXICATED[.] 1ST
# 2                        NaN  03/05/1997                  IMPROPER DRIVING
# 3                        NaN  04/21/2015      AP-G POSSESSION OF MARIJUANA
# 4                        NaN  10/09/1993                     GRAND LARCENY
# ...                      ...         ...                               ...
# 1071603                  NaN         NaN                  IMPROPER BACKING
# 1071604                  NaN         NaN                    SPEEDING 51/35
# 1071605                  NaN  07/19/2008                 CREDIT CARD FRAUD
# 1071606            46.2-1003  07/04/2002                    76/65 SPEEDING
# 1071607             46.2-870         NaN            RECKLESS DRIVING 81/45
#
#          Charge Type Class CodeSection                   Commenced by  \
# 0        Misdemeanor   NaN    46.2-862  General District Court Appeal
# 1        Misdemeanor     1  A.18.2-266  General District Court Appeal
# 2                  M     O    46.2-869  General District Court Appeal
# 3        Misdemeanor     U  18.2-250.1  General District Court Appeal
# 4                  F     O     18.2-95                     Indictment
# ...              ...   ...         ...                            ...
# 1071603  Misdemeanor   NaN    46.2-848  General District Court Appeal
# 1071604   Infraction   NaN  A.46.2-875  General District Court Appeal
# 1071605       Felony     6    18.2-195                     Indictment
# 1071606  Misdemeanor     1  F.46.2-870  General District Court Appeal
# 1071607  Misdemeanor     1  A.46.2-862  General District Court Appeal
#
#                        Concluded By  \
# 0        Trial - Judge With Witness
# 1                      Trial - Jury
# 2        Trial - Judge With Witness
# 3        Trial - Judge With Witness
# 4                       Guilty Plea
# ...                             ...
# 1071603  Trial - Judge With Witness
# 1071604  Trial - Judge With Witness
# 1071605                 Guilty Plea
# 1071606                 Guilty Plea
# 1071607                 Guilty Plea
#
#                               ConcurrentConsecutive     Costs  \
# 0                                               NaN    $88.00
# 1                                               NaN  $1473.00
# 2                                               NaN    $71.00
# 3                                               NaN   $477.50
# 4                                               NaN       NaN
# ...                                             ...       ...
# 1071603                                         NaN   $131.00
# 1071604                                         NaN   $128.00
# 1071605  Sentence Is Run Consecutively With Another   $825.00
# 1071606                                         NaN    $83.00
# 1071607                                         NaN   $201.00
#
#                  Court/DMV Surrender         DOB                   Defendant  \
# 0        License Was Not Surrendered  03/15/****        A GHAYYADA[.] AMER O
# 1        License Was Not Surrendered  01/09/****    A'SIM[.] ZAHIR RAKIN; JR
# 2                                NaN  11/03/****    AADAHL[.] CHRISTOPHER P.
# 3        License Was Not Surrendered  06/19/****    AAGESEN[.] KEVIN MICHAEL
# 4                                NaN  04/27/****           AAGLAN[.] MELISSA
# ...                              ...         ...                         ...
# 1071603                          NaN  08/12/****  ZYROWSKI[.] SCOTT THEODORE
# 1071604                          NaN  03/27/****         ZYSK[.] ELIZABETH G
# 1071605                          NaN  05/10/****  ZYVOLOSKI[.] MICHAEL A; II
# 1071606                          NaN  08/01/****         ZYWACZISISKI[.] JAN
# 1071607                          NaN  08/21/****      ZZAMAN[.] KAZI ESTEY K
#
#         Disposition Date Driver Improvement Clinic Driving Restrictions  \
# 0             12/11/2002                       NaN                  Yes
# 1             02/17/2012                       NaN                  Yes
# 2             06/24/1997                       NaN                  NaN
# 3             10/01/2015                       NaN                  NaN
# 4             01/18/1994                       NaN                  NaN
# ...                  ...                       ...                  ...
# 1071603       02/19/2010                       NaN                  NaN
# 1071604       09/03/2004                       NaN                  NaN
# 1071605       01/26/2009                       NaN                  NaN
# 1071606       11/27/2002                       NaN                  NaN
# 1071607       11/13/2015                       NaN                  NaN
#
#               Filed Fine Amount Fines/Cost Paid Jail/Penitentiary Life/Death  \
# 0        10/15/2002     $500.00             Yes              Jail        NaN
# 1        06/15/2011    $1250.00             NaN              Jail        NaN
# 2        04/29/1997     $250.00             Yes               NaN        NaN
# 3        07/09/2015     $350.00             NaN               NaN        NaN
# 4        01/03/1994         NaN             NaN               NaN        NaN
# ...             ...         ...             ...               ...        ...
# 1071603  12/02/2009      $30.00             Yes               NaN        NaN
# 1071604  08/09/2004      $35.00             Yes               NaN        NaN
# 1071605  09/02/2008         NaN             Yes      Penitentiary        NaN
# 1071606  10/17/2002     $125.00             Yes               NaN        NaN
# 1071607  10/23/2015     $200.00             Yes               NaN        NaN
#
#                    Locality Military Offense Date  \
# 0        COMMONWEALTH OF VA      NaN   08/23/2002
# 1        COMMONWEALTH OF VA      NaN   11/20/2010
# 2        COMMONWEALTH OF VA      NaN   03/05/1997
# 3        COMMONWEALTH OF VA      NaN   04/21/2015
# 4        COMMONWEALTH OF VA      NaN   09/29/1993
# ...                     ...      ...          ...
# 1071603  COMMONWEALTH OF VA      NaN   07/06/2009
# 1071604          CHESAPEAKE      NaN   05/25/2004
# 1071605  COMMONWEALTH OF VA      NaN   06/10/2008
# 1071606  COMMONWEALTH OF VA      NaN   07/04/2002
# 1071607  COMMONWEALTH OF VA      NaN   08/08/2015
#
#         Operator License Suspension Time Probation Starts Probation Time  \
# 0                             6 Month(s)              NaN            NaN
# 1                            12 Month(s)              NaN            NaN
# 2                                    NaN              NaN            NaN
# 3                             6 Month(s)              NaN            NaN
# 4                                    NaN              NaN            NaN
# ...                                  ...              ...            ...
# 1071603                              NaN              NaN            NaN
# 1071604                              NaN              NaN            NaN
# 1071605                              NaN              NaN      2 Year(s)
# 1071606                              NaN              NaN            NaN
# 1071607                              NaN              NaN            NaN
#
#         Probation Type Program Type  \
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 1071603            NaN          NaN
# 1071604            NaN          NaN
# 1071605     Supervised          NaN
# 1071606            NaN          NaN
# 1071607            NaN          NaN
#
#                                                Race Restitution Amount  \
# 0                                             White                NaN
# 1                                             Black              $0.00
# 2                                             White                NaN
# 3                         Asian Or Pacific Islander              $0.00
# 4                                             White                NaN
# ...                                             ...                ...
# 1071603                                       White              $0.00
# 1071604                                       White                NaN
# 1071605                                       White            $160.06
# 1071606                                       White                NaN
# 1071607  Other (Includes Not Applicable[.] Unknown)              $0.00
#
#         Restitution Paid            Sentence Suspended  \
# 0                    NaN  0 Year(s)0 Month(s)90 Day(s)
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
# ...                  ...                           ...
# 1071603              NaN                           NaN
# 1071604              NaN                           NaN
# 1071605              NaN                     2 Year(s)
# 1071606              NaN                           NaN
# 1071607              NaN                           NaN
#
#                         Sentence Time     Sex Traffic Fatality  \
# 0        0 Year(s)0 Month(s)90 Day(s)    Male              NaN
# 1                            7 Day(s)    Male               No
# 2                                 NaN    Male              NaN
# 3                                 NaN    Male               No
# 4                                 NaN  Female              NaN
# ...                               ...     ...              ...
# 1071603                           NaN    Male               No
# 1071604                           NaN  Female              NaN
# 1071605                     2 Year(s)    Male              NaN
# 1071606                           NaN    Male              NaN
# 1071607                           NaN    Male               No
#
#         VA Alcohol Safety Action                              county  \
# 0                            NaN                Louisa Circuit Court
# 1                            Yes          Roanoke City Circuit Court
# 2                            NaN  York County/Poquoson Circuit Court
# 3                            NaN        Prince William Circuit Court
# 4                            NaN        Virginia Beach Circuit Court
# ...                          ...                                 ...
# 1071603                      NaN              Stafford Circuit Court
# 1071604                      NaN            Chesapeake Circuit Court
# 1071605                      NaN               Loudoun Circuit Court
# 1071606                      NaN               Pulaski Circuit Court
# 1071607                      NaN               Loudoun Circuit Court
#
#           time_step  day  month  year                 sentence_time  \
# 0        -83.638356   11     12  2002  0 Year(s)0 Month(s)90 Day(s)
# 1         26.558904   17      2  2012                      7 Day(s)
# 2       -149.210959   24      6  1997                             0
# 3         70.032877    1     10  2015                             0
# 4       -190.408219   18      1  1994                             0
# ...             ...  ...    ...   ...                           ...
# 1071603    2.624658   19      2  2010                             0
# 1071604  -62.901370    3      9  2004                             0
# 1071605  -10.145205   26      1  2009                     2 Year(s)
# 1071606  -84.112329   27     11  2002                             0
# 1071607   71.427397   13     11  2015                             0
#
#                    sentence_suspended  \
# 0        0 Year(s)0 Month(s)90 Day(s)
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 1071603                             0
# 1071604                             0
# 1071605                     2 Year(s)
# 1071606                             0
# 1071607                             0
#
#                                                  person_id  \
# 0        A GHAYYADA[.] AMER O03/15/****LYNCHBURG[.] VA ...
# 1        A'SIM[.] ZAHIR RAKIN; JR01/09/****ROANOKE[.] V...
# 2        AADAHL[.] CHRISTOPHER P.11/03/****WILLIAMSBURG...
# 3        AAGESEN[.] KEVIN MICHAEL06/19/****WOODBRIDGE[....
# 4          AAGLAN[.] MELISSA04/27/****VIRGINIA BEACH[.] VA
# ...                                                    ...
# 1071603  ZYROWSKI[.] SCOTT THEODORE08/12/****PORT ORANG...
# 1071604  ZYSK[.] ELIZABETH G03/27/****CHESAPEAKE[.] VA ...
# 1071605  ZYVOLOSKI[.] MICHAEL A; II05/10/****CITY UNKNO...
# 1071606  ZYWACZISISKI[.] JAN08/01/****POMPANO BEACH FL ...
# 1071607  ZZAMAN[.] KAZI ESTEY K08/21/****CHANTILLY[.] V...
#
#          compartment_duration  CONSPIRACY  FIRST_DEGREE_MURDER  \
# 0                    0.000000       False                False
# 1                    0.230137       False                False
# 2                    0.000000       False                False
# 3                    0.000000       False                False
# 4                    0.000000       False                False
# ...                       ...         ...                  ...
# 1071603              0.000000       False                False
# 1071604              0.000000       False                False
# 1071605              0.000000       False                False
# 1071606              0.000000       False                False
# 1071607              0.000000       False                False
#
#          SECOND_DEGREE_MURDER  CAPITAL_MURDER  OTHER_MURDER  DRUG_POSSESSION  \
# 0                       False           False         False            False
# 1                       False           False         False            False
# 2                       False           False         False            False
# 3                       False           False         False             True
# 4                       False           False         False            False
# ...                       ...             ...           ...              ...
# 1071603                 False           False         False            False
# 1071604                 False           False         False            False
# 1071605                 False           False         False            False
# 1071606                 False           False         False            False
# 1071607                 False           False         False            False
#
#          DRUG_SALE  DRUG_OTHER  ARSON  SEX_OFFENSE    DWI  WEAPON  BURGLARY  \
# 0            False       False  False        False  False   False     False
# 1            False       False  False        False   True   False     False
# 2            False       False  False        False  False   False     False
# 3            False       False  False        False  False   False     False
# 4            False       False  False        False  False   False     False
# ...            ...         ...    ...          ...    ...     ...       ...
# 1071603      False       False  False        False  False   False     False
# 1071604      False       False  False        False  False   False     False
# 1071605      False       False  False        False  False   False     False
# 1071606      False       False  False        False  False   False     False
# 1071607      False       False  False        False  False   False     False
#
#          ROBBERY  LARCENY  ASSAULT   RAPE  KIDNAPPING  MANSLAUGHTER  crimes  \
# 0          False    False    False  False       False         False       1
# 1          False    False    False  False       False         False       2
# 2          False    False    False  False       False         False       1
# 3          False    False    False  False       False         False       1
# 4          False     True    False  False       False         False       2
# ...          ...      ...      ...    ...         ...           ...     ...
# 1071603    False    False    False  False       False         False       1
# 1071604    False    False    False  False       False         False       1
# 1071605    False    False    False  False       False         False       1
# 1071606    False    False    False  False       False         False       1
# 1071607    False    False    False  False       False         False       1
#
#          CONSPIRACY_ANY  DRUG_POSSESSION_ANY  DRUG_SALE_ANY  DRUG_OTHER_ANY  \
# 0                 False                False          False           False
# 1                 False                False          False           False
# 2                 False                False          False           False
# 3                 False                 True          False           False
# 4                 False                False          False           False
# ...                 ...                  ...            ...             ...
# 1071603           False                False          False           False
# 1071604           False                False          False           False
# 1071605           False                False          False           False
# 1071606           False                False          False           False
# 1071607           False                False          False           False
#
#          KIDNAPPING_ANY  MANSLAUGHTER_ANY  LARCENY_ANY  WEAPON_ANY  \
# 0                 False             False        False       False
# 1                 False             False        False       False
# 2                 False             False        False       False
# 3                 False             False        False       False
# 4                 False             False         True       False
# ...                 ...               ...          ...         ...
# 1071603           False             False        False       False
# 1071604           False             False        False       False
# 1071605           False             False        False       False
# 1071606           False             False        False       False
# 1071607           False             False        False       False
#
#          ASSAULT_ANY  ROBBERY_ANY  BURGLARY_ANY  DWI_ANY  RAPE_ANY  \
# 0              False        False         False    False     False
# 1              False        False         False     True     False
# 2              False        False         False    False     False
# 3              False        False         False    False     False
# 4              False        False          True    False     False
# ...              ...          ...           ...      ...       ...
# 1071603        False        False         False    False     False
# 1071604        False        False         False    False     False
# 1071605        False        False         False    False     False
# 1071606        False        False         False    False     False
# 1071607        False        False         False    False     False
#
#          SEX_OFFENSE_ANY  ARSON_ANY  FIRST_DEGREE_MURDER_ANY  \
# 0                  False      False                    False
# 1                  False      False                    False
# 2                  False      False                    False
# 3                  False      False                    False
# 4                  False      False                    False
# ...                  ...        ...                      ...
# 1071603            False      False                    False
# 1071604            False      False                    False
# 1071605            False      False                    False
# 1071606            False      False                    False
# 1071607            False      False                    False
#
#          SECOND_DEGREE_MURDER_ANY  OTHER_MURDER_ANY  CAPITAL_MURDER_ANY  \
# 0                           False             False               False
# 1                           False             False               False
# 2                           False             False               False
# 3                           False             False               False
# 4                           False             False               False
# ...                           ...               ...                 ...
# 1071603                     False             False               False
# 1071604                     False             False               False
# 1071605                     False             False               False
# 1071606                     False             False               False
# 1071607                     False             False               False
#
#          total_sentence_months       crime_type
# 0                     0.000000              NaN
# 1                     0.230137              DWI
# 2                     0.000000              NaN
# 3                     0.000000  DRUG_POSSESSION
# 4                     0.000000          LARCENY
# ...                        ...              ...
# 1071603               0.000000              NaN
# 1071604               0.000000              NaN
# 1071605               0.000000              NaN
# 1071606               0.000000              NaN
# 1071607               0.000000              NaN
#
# [1071608 rows x 90 columns]

# %%
# Check sentencing data to determine age of offenders when sentenced
raw_sent = pd.concat([
    pd.read_csv(f'../state/VA/VA_data/sentencing_data/sentencing_{i}.csv', encoding = "ISO-8859-1") for i in range(2019,2022)
])

under_25 = 0
total = 0

for i, row in raw_sent.iterrows():
    sentence_year = row['Calendar Year of Sentencing']
    birth_year = row['Offender Birth Year']
    
    sentencing_age = sentence_year - birth_year
        
    if sentencing_age <= 25:
        under_25 += 1
    
    total += 1
        
# Proportion of inmates incarcerated before 25
INCARCERATED_BEFORE_25 = under_25/total
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3001792234.py:3: DtypeWarning: Columns (40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f'../state/VA/VA_data/sentencing_data/sentencing_{i}.csv', encoding = "ISO-8859-1") for i in range(2019,2022)
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3001792234.py:3: DtypeWarning: Columns (40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f'../state/VA/VA_data/sentencing_data/sentencing_{i}.csv', encoding = "ISO-8859-1") for i in range(2019,2022)
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3001792234.py:3: DtypeWarning: Columns (34,35,37,38,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f'../state/VA/VA_data/sentencing_data/sentencing_{i}.csv', encoding = "ISO-8859-1") for i in range(2019,2022)

# %%
sdc_data
# Out:
#                           Address         Amended Charge Amended Charge Type  \
# 0           LYNCHBURG[.] VA 24506                    NaN                 NaN
# 1             ROANOKE[.] VA 24017                    NaN                 NaN
# 2        WILLIAMSBURG[.] VA 23188                    NaN                 NaN
# 3          WOODBRIDGE[.] VA 22191                    NaN                 NaN
# 4            VIRGINIA BEACH[.] VA                    NaN                 NaN
# ...                           ...                    ...                 ...
# 1071603   PORT ORANGE[.] FL 32129                    NaN                 NaN
# 1071604    CHESAPEAKE[.] VA 23323                    NaN                 NaN
# 1071605         CITY UNKNOWN[.]VA                    NaN                 NaN
# 1071606    POMPANO BEACH FL 33060     IMPROPER EQUIPMENT         Misdemeanor
# 1071607     CHANTILLY[.] VA 20152  SP 20+ MPH OVER LIMIT          Infraction
#
#         Amended Code Section Arrest Date                            Charge  \
# 0                        NaN         NaN    RECKLESS DRIVING (SP 95/65 MR)
# 1                        NaN  12/05/2012  DRIVING WHILE INTOXICATED[.] 1ST
# 2                        NaN  03/05/1997                  IMPROPER DRIVING
# 3                        NaN  04/21/2015      AP-G POSSESSION OF MARIJUANA
# 4                        NaN  10/09/1993                     GRAND LARCENY
# ...                      ...         ...                               ...
# 1071603                  NaN         NaN                  IMPROPER BACKING
# 1071604                  NaN         NaN                    SPEEDING 51/35
# 1071605                  NaN  07/19/2008                 CREDIT CARD FRAUD
# 1071606            46.2-1003  07/04/2002                    76/65 SPEEDING
# 1071607             46.2-870         NaN            RECKLESS DRIVING 81/45
#
#          Charge Type Class CodeSection                   Commenced by  \
# 0        Misdemeanor   NaN    46.2-862  General District Court Appeal
# 1        Misdemeanor     1  A.18.2-266  General District Court Appeal
# 2                  M     O    46.2-869  General District Court Appeal
# 3        Misdemeanor     U  18.2-250.1  General District Court Appeal
# 4                  F     O     18.2-95                     Indictment
# ...              ...   ...         ...                            ...
# 1071603  Misdemeanor   NaN    46.2-848  General District Court Appeal
# 1071604   Infraction   NaN  A.46.2-875  General District Court Appeal
# 1071605       Felony     6    18.2-195                     Indictment
# 1071606  Misdemeanor     1  F.46.2-870  General District Court Appeal
# 1071607  Misdemeanor     1  A.46.2-862  General District Court Appeal
#
#                        Concluded By  \
# 0        Trial - Judge With Witness
# 1                      Trial - Jury
# 2        Trial - Judge With Witness
# 3        Trial - Judge With Witness
# 4                       Guilty Plea
# ...                             ...
# 1071603  Trial - Judge With Witness
# 1071604  Trial - Judge With Witness
# 1071605                 Guilty Plea
# 1071606                 Guilty Plea
# 1071607                 Guilty Plea
#
#                               ConcurrentConsecutive     Costs  \
# 0                                               NaN    $88.00
# 1                                               NaN  $1473.00
# 2                                               NaN    $71.00
# 3                                               NaN   $477.50
# 4                                               NaN       NaN
# ...                                             ...       ...
# 1071603                                         NaN   $131.00
# 1071604                                         NaN   $128.00
# 1071605  Sentence Is Run Consecutively With Another   $825.00
# 1071606                                         NaN    $83.00
# 1071607                                         NaN   $201.00
#
#                  Court/DMV Surrender         DOB                   Defendant  \
# 0        License Was Not Surrendered  03/15/****        A GHAYYADA[.] AMER O
# 1        License Was Not Surrendered  01/09/****    A'SIM[.] ZAHIR RAKIN; JR
# 2                                NaN  11/03/****    AADAHL[.] CHRISTOPHER P.
# 3        License Was Not Surrendered  06/19/****    AAGESEN[.] KEVIN MICHAEL
# 4                                NaN  04/27/****           AAGLAN[.] MELISSA
# ...                              ...         ...                         ...
# 1071603                          NaN  08/12/****  ZYROWSKI[.] SCOTT THEODORE
# 1071604                          NaN  03/27/****         ZYSK[.] ELIZABETH G
# 1071605                          NaN  05/10/****  ZYVOLOSKI[.] MICHAEL A; II
# 1071606                          NaN  08/01/****         ZYWACZISISKI[.] JAN
# 1071607                          NaN  08/21/****      ZZAMAN[.] KAZI ESTEY K
#
#         Disposition Date Driver Improvement Clinic Driving Restrictions  \
# 0             12/11/2002                       NaN                  Yes
# 1             02/17/2012                       NaN                  Yes
# 2             06/24/1997                       NaN                  NaN
# 3             10/01/2015                       NaN                  NaN
# 4             01/18/1994                       NaN                  NaN
# ...                  ...                       ...                  ...
# 1071603       02/19/2010                       NaN                  NaN
# 1071604       09/03/2004                       NaN                  NaN
# 1071605       01/26/2009                       NaN                  NaN
# 1071606       11/27/2002                       NaN                  NaN
# 1071607       11/13/2015                       NaN                  NaN
#
#               Filed Fine Amount Fines/Cost Paid Jail/Penitentiary Life/Death  \
# 0        10/15/2002     $500.00             Yes              Jail        NaN
# 1        06/15/2011    $1250.00             NaN              Jail        NaN
# 2        04/29/1997     $250.00             Yes               NaN        NaN
# 3        07/09/2015     $350.00             NaN               NaN        NaN
# 4        01/03/1994         NaN             NaN               NaN        NaN
# ...             ...         ...             ...               ...        ...
# 1071603  12/02/2009      $30.00             Yes               NaN        NaN
# 1071604  08/09/2004      $35.00             Yes               NaN        NaN
# 1071605  09/02/2008         NaN             Yes      Penitentiary        NaN
# 1071606  10/17/2002     $125.00             Yes               NaN        NaN
# 1071607  10/23/2015     $200.00             Yes               NaN        NaN
#
#                    Locality Military Offense Date  \
# 0        COMMONWEALTH OF VA      NaN   08/23/2002
# 1        COMMONWEALTH OF VA      NaN   11/20/2010
# 2        COMMONWEALTH OF VA      NaN   03/05/1997
# 3        COMMONWEALTH OF VA      NaN   04/21/2015
# 4        COMMONWEALTH OF VA      NaN   09/29/1993
# ...                     ...      ...          ...
# 1071603  COMMONWEALTH OF VA      NaN   07/06/2009
# 1071604          CHESAPEAKE      NaN   05/25/2004
# 1071605  COMMONWEALTH OF VA      NaN   06/10/2008
# 1071606  COMMONWEALTH OF VA      NaN   07/04/2002
# 1071607  COMMONWEALTH OF VA      NaN   08/08/2015
#
#         Operator License Suspension Time Probation Starts Probation Time  \
# 0                             6 Month(s)              NaN            NaN
# 1                            12 Month(s)              NaN            NaN
# 2                                    NaN              NaN            NaN
# 3                             6 Month(s)              NaN            NaN
# 4                                    NaN              NaN            NaN
# ...                                  ...              ...            ...
# 1071603                              NaN              NaN            NaN
# 1071604                              NaN              NaN            NaN
# 1071605                              NaN              NaN      2 Year(s)
# 1071606                              NaN              NaN            NaN
# 1071607                              NaN              NaN            NaN
#
#         Probation Type Program Type  \
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
# ...                ...          ...
# 1071603            NaN          NaN
# 1071604            NaN          NaN
# 1071605     Supervised          NaN
# 1071606            NaN          NaN
# 1071607            NaN          NaN
#
#                                                Race Restitution Amount  \
# 0                                             White                NaN
# 1                                             Black              $0.00
# 2                                             White                NaN
# 3                         Asian Or Pacific Islander              $0.00
# 4                                             White                NaN
# ...                                             ...                ...
# 1071603                                       White              $0.00
# 1071604                                       White                NaN
# 1071605                                       White            $160.06
# 1071606                                       White                NaN
# 1071607  Other (Includes Not Applicable[.] Unknown)              $0.00
#
#         Restitution Paid            Sentence Suspended  \
# 0                    NaN  0 Year(s)0 Month(s)90 Day(s)
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
# ...                  ...                           ...
# 1071603              NaN                           NaN
# 1071604              NaN                           NaN
# 1071605              NaN                     2 Year(s)
# 1071606              NaN                           NaN
# 1071607              NaN                           NaN
#
#                         Sentence Time     Sex Traffic Fatality  \
# 0        0 Year(s)0 Month(s)90 Day(s)    Male              NaN
# 1                            7 Day(s)    Male               No
# 2                                 NaN    Male              NaN
# 3                                 NaN    Male               No
# 4                                 NaN  Female              NaN
# ...                               ...     ...              ...
# 1071603                           NaN    Male               No
# 1071604                           NaN  Female              NaN
# 1071605                     2 Year(s)    Male              NaN
# 1071606                           NaN    Male              NaN
# 1071607                           NaN    Male               No
#
#         VA Alcohol Safety Action                              county  \
# 0                            NaN                Louisa Circuit Court
# 1                            Yes          Roanoke City Circuit Court
# 2                            NaN  York County/Poquoson Circuit Court
# 3                            NaN        Prince William Circuit Court
# 4                            NaN        Virginia Beach Circuit Court
# ...                          ...                                 ...
# 1071603                      NaN              Stafford Circuit Court
# 1071604                      NaN            Chesapeake Circuit Court
# 1071605                      NaN               Loudoun Circuit Court
# 1071606                      NaN               Pulaski Circuit Court
# 1071607                      NaN               Loudoun Circuit Court
#
#           time_step  day  month  year                 sentence_time  \
# 0        -83.638356   11     12  2002  0 Year(s)0 Month(s)90 Day(s)
# 1         26.558904   17      2  2012                      7 Day(s)
# 2       -149.210959   24      6  1997                             0
# 3         70.032877    1     10  2015                             0
# 4       -190.408219   18      1  1994                             0
# ...             ...  ...    ...   ...                           ...
# 1071603    2.624658   19      2  2010                             0
# 1071604  -62.901370    3      9  2004                             0
# 1071605  -10.145205   26      1  2009                     2 Year(s)
# 1071606  -84.112329   27     11  2002                             0
# 1071607   71.427397   13     11  2015                             0
#
#                    sentence_suspended  \
# 0        0 Year(s)0 Month(s)90 Day(s)
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
# ...                               ...
# 1071603                             0
# 1071604                             0
# 1071605                     2 Year(s)
# 1071606                             0
# 1071607                             0
#
#                                                  person_id  \
# 0        A GHAYYADA[.] AMER O03/15/****LYNCHBURG[.] VA ...
# 1        A'SIM[.] ZAHIR RAKIN; JR01/09/****ROANOKE[.] V...
# 2        AADAHL[.] CHRISTOPHER P.11/03/****WILLIAMSBURG...
# 3        AAGESEN[.] KEVIN MICHAEL06/19/****WOODBRIDGE[....
# 4          AAGLAN[.] MELISSA04/27/****VIRGINIA BEACH[.] VA
# ...                                                    ...
# 1071603  ZYROWSKI[.] SCOTT THEODORE08/12/****PORT ORANG...
# 1071604  ZYSK[.] ELIZABETH G03/27/****CHESAPEAKE[.] VA ...
# 1071605  ZYVOLOSKI[.] MICHAEL A; II05/10/****CITY UNKNO...
# 1071606  ZYWACZISISKI[.] JAN08/01/****POMPANO BEACH FL ...
# 1071607  ZZAMAN[.] KAZI ESTEY K08/21/****CHANTILLY[.] V...
#
#          compartment_duration  CONSPIRACY  FIRST_DEGREE_MURDER  \
# 0                    0.000000       False                False
# 1                    0.230137       False                False
# 2                    0.000000       False                False
# 3                    0.000000       False                False
# 4                    0.000000       False                False
# ...                       ...         ...                  ...
# 1071603              0.000000       False                False
# 1071604              0.000000       False                False
# 1071605              0.000000       False                False
# 1071606              0.000000       False                False
# 1071607              0.000000       False                False
#
#          SECOND_DEGREE_MURDER  CAPITAL_MURDER  OTHER_MURDER  DRUG_POSSESSION  \
# 0                       False           False         False            False
# 1                       False           False         False            False
# 2                       False           False         False            False
# 3                       False           False         False             True
# 4                       False           False         False            False
# ...                       ...             ...           ...              ...
# 1071603                 False           False         False            False
# 1071604                 False           False         False            False
# 1071605                 False           False         False            False
# 1071606                 False           False         False            False
# 1071607                 False           False         False            False
#
#          DRUG_SALE  DRUG_OTHER  ARSON  SEX_OFFENSE    DWI  WEAPON  BURGLARY  \
# 0            False       False  False        False  False   False     False
# 1            False       False  False        False   True   False     False
# 2            False       False  False        False  False   False     False
# 3            False       False  False        False  False   False     False
# 4            False       False  False        False  False   False     False
# ...            ...         ...    ...          ...    ...     ...       ...
# 1071603      False       False  False        False  False   False     False
# 1071604      False       False  False        False  False   False     False
# 1071605      False       False  False        False  False   False     False
# 1071606      False       False  False        False  False   False     False
# 1071607      False       False  False        False  False   False     False
#
#          ROBBERY  LARCENY  ASSAULT   RAPE  KIDNAPPING  MANSLAUGHTER  crimes  \
# 0          False    False    False  False       False         False       1
# 1          False    False    False  False       False         False       2
# 2          False    False    False  False       False         False       1
# 3          False    False    False  False       False         False       1
# 4          False     True    False  False       False         False       2
# ...          ...      ...      ...    ...         ...           ...     ...
# 1071603    False    False    False  False       False         False       1
# 1071604    False    False    False  False       False         False       1
# 1071605    False    False    False  False       False         False       1
# 1071606    False    False    False  False       False         False       1
# 1071607    False    False    False  False       False         False       1
#
#          CONSPIRACY_ANY  DRUG_POSSESSION_ANY  DRUG_SALE_ANY  DRUG_OTHER_ANY  \
# 0                 False                False          False           False
# 1                 False                False          False           False
# 2                 False                False          False           False
# 3                 False                 True          False           False
# 4                 False                False          False           False
# ...                 ...                  ...            ...             ...
# 1071603           False                False          False           False
# 1071604           False                False          False           False
# 1071605           False                False          False           False
# 1071606           False                False          False           False
# 1071607           False                False          False           False
#
#          KIDNAPPING_ANY  MANSLAUGHTER_ANY  LARCENY_ANY  WEAPON_ANY  \
# 0                 False             False        False       False
# 1                 False             False        False       False
# 2                 False             False        False       False
# 3                 False             False        False       False
# 4                 False             False         True       False
# ...                 ...               ...          ...         ...
# 1071603           False             False        False       False
# 1071604           False             False        False       False
# 1071605           False             False        False       False
# 1071606           False             False        False       False
# 1071607           False             False        False       False
#
#          ASSAULT_ANY  ROBBERY_ANY  BURGLARY_ANY  DWI_ANY  RAPE_ANY  \
# 0              False        False         False    False     False
# 1              False        False         False     True     False
# 2              False        False         False    False     False
# 3              False        False         False    False     False
# 4              False        False          True    False     False
# ...              ...          ...           ...      ...       ...
# 1071603        False        False         False    False     False
# 1071604        False        False         False    False     False
# 1071605        False        False         False    False     False
# 1071606        False        False         False    False     False
# 1071607        False        False         False    False     False
#
#          SEX_OFFENSE_ANY  ARSON_ANY  FIRST_DEGREE_MURDER_ANY  \
# 0                  False      False                    False
# 1                  False      False                    False
# 2                  False      False                    False
# 3                  False      False                    False
# 4                  False      False                    False
# ...                  ...        ...                      ...
# 1071603            False      False                    False
# 1071604            False      False                    False
# 1071605            False      False                    False
# 1071606            False      False                    False
# 1071607            False      False                    False
#
#          SECOND_DEGREE_MURDER_ANY  OTHER_MURDER_ANY  CAPITAL_MURDER_ANY  \
# 0                           False             False               False
# 1                           False             False               False
# 2                           False             False               False
# 3                           False             False               False
# 4                           False             False               False
# ...                           ...               ...                 ...
# 1071603                     False             False               False
# 1071604                     False             False               False
# 1071605                     False             False               False
# 1071606                     False             False               False
# 1071607                     False             False               False
#
#          total_sentence_months       crime_type
# 0                     0.000000              NaN
# 1                     0.230137              DWI
# 2                     0.000000              NaN
# 3                     0.000000  DRUG_POSSESSION
# 4                     0.000000          LARCENY
# ...                        ...              ...
# 1071603               0.000000              NaN
# 1071604               0.000000              NaN
# 1071605               0.000000              NaN
# 1071606               0.000000              NaN
# 1071607               0.000000              NaN
#
# [1071608 rows x 90 columns]

# %%
# This is to make it easier to label data based on violation codes
codes = sdc_data['CodeSection'].unique().astype(str)
charges = sdc_data['Charge'].unique().astype(str)

def containing(a, substr):
    b = []
    for el in a:
        if substr.lower() in el.lower():
            b.append(el)
    return b

containing(codes, "18.2-374.1")
# Out:
# ['18.2-374.1',
#  '18.2-374.1 B1)',
#  '18.2-374.1B2',
#  '18.2-374.1-B(2)',
#  'B.18.2-374.1',
#  '18.2-374.1(B)',
#  '18.2-374.1(B[.]2)',
#  '18.2-374.1(B)(3',
#  '18.2-374.1B3',
#  '18.2-374.1(B)4',
#  '18.2-374.1(B[.]3)',
#  '18.2-374.1(B)(4',
#  '18.2-374.1B1&.2',
#  '18.2-374.1B(1)',
#  '18.2-374.1B(2)',
#  '18.2-374.1 B(1)',
#  '18.2-374.1(B)2',
#  '18.2-374.1A',
#  '18.2-374.1B4',
#  '18.2-374.1(B[.]1)',
#  '18.2-374.1C2',
#  '18.2-374.1 B. 2',
#  '18.2-374.1(B)(2',
#  '18.2-374.1(B)(1',
#  '18.2-374.1(B2)',
#  '18.2-374.1.1',
#  '18.2-374.1(C)',
#  'C.18.2-374.1',
#  'A.18.2-374.1',
#  '18.2-374.1 B.1']

# %%
'''
Modeling Assumptions made here:
 - Child-adult distinctions are not made unless under separate codes. Codes are treated under highest severity (ex. in alternative A, 18.2-67.1 committed against an adult is treated as 18.2-67.1 committed against a child)
 - All offenses are assumed repeat where those rules apply (ex. in alternative A, 18.2.30 is always in the 30-year tier)
 - Subsection-level distinctions are not made. If a tier includes some subsection of a code, the whole code is included
 - Inchoate offenses are not factored in
'''
# Note: We can't see repeat offenses in the data as-is, so all rules applying to repeat offenses will be applied to all offense of that type
## This means our model of the policy will generally let people out later, so our estimates will be more conservative
# This also does not include any of the inchoate conviction clauses
# 

policy_scenarios = {
    'original': [
        [],
        [],
        ['F1', '18.2-31', '18.2-30', '18.2-40', '18.2-45', '18.2-46.5', '18.2-46.6', '18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2-274.1', '18.2-355', '18.2-371.1', '18.2-481'],
        ['18.2-32', '18.2-41', '18.2-51', '18.2-51.1', '18.2-51.2', '18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2.90', '18.2-77', '18.2-79', '18.2-80', '18.2-79', '18.2-80', '18.2-79', '18.2-374.1C', '18.2-374.1(C)'],
        ['F*']
    ],
    'a': [
        [],
        ['F1', '18.2.31', '18.2.30'],
        ['18.2-40', '18.2-45', '18.2-46.5', '18.2-46.6', '18.2-46.6', '18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2-64.2', '18.2-274.1', '18.2-274.1', '18.2-355', '18.2-371.1', '18.2-481'],
        ['18.2-32', '18.2-41', '18.2-51', '18.2-51.1', '18.2-51.2', '18.2-61', '18.2-90', '18.2-77', '18.2-79', '18.2-80', '18.2-374.1'],
        ['F*']
    ],
    'b': [
        ['18.2-31', '18.2-30'],
        [],
        ['18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2-46.6', '18.2-274.1', '18.2-40', '18.2-45', '18.2-481', '18.2-371.1'],
        [],
        ['F*']
    ],
    'c': [
        ['18.2.31', '18.2-30'],
        [],
        ['18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2-46.6', '18.2-274.1', '18.2-40', '18.2-45', '18.2-481', '18.2-371.1'],
        ['18.2-32', '18.2-61', '18.2-67.1', '18.2-67.2', '18.2-67.3', '18.2-63', '18.2-64.1', '18.2-64.2', '18.2-51', '18.2-77', '18.2-79', '18.2-80', '18.2-41', '18.2-51', '18.2-51.1', '18.2-79', '18.2-374.1'],
        ['F*']
    ]
}

# Here you can change the version of the bill we're using
scenario = 'original'

# %%
sdc_data['Charge Type'].unique()
# Out:
# array(['Misdemeanor', 'M', 'F', 'Felony', 'Infraction', 'Civil', nan,
#        'Other (Animal Violations[.] Bond Appeals)', 'I'], dtype=object)

# %%
# Assign tiers for a given policy scenario
for tier, tier_codes in enumerate(policy_scenarios[scenario]):
    for code in tier_codes:
        conditions = None
        
        # Class-1 felonies
        if code == 'F1':
            conditions = (sdc_data['Class'] == '1') & (sdc_data['Charge Type'].isin(['F', 'Felony']))
        # All other felonies
        if code == 'F*':
            conditions = sdc_data['Charge Type'].isin(['F', 'Felony'])
        # Actual codes
        else:
            # This is for catching minor abberations in how codes are written out
            possible_codes = containing(codes, code) + containing(codes, code.replace('-','.'))
            conditions = sdc_data['CodeSection'].isin(possible_codes)   

        sdc_data.loc[conditions & sdc_data['tier'].isna(), 'tier'] = tier

# %%
sdc_data.loc[sdc_data['tier'].isna(), 'tier'] = 0

# %%
sdc_data[sdc_data['Charge'] == 'MURDER']['CodeSection']
# Out:
# 490        Z.18.2-32
# 1092       A.18.2-32
# 1706         18.2-32
# 1876       A.18.2-32
# 2872         18.2-32
#              ...
# 1069348      18.2-32
# 1069663      18.2-32
# 1070613      18.2-33
# 1070928      18.2-33
# 1071511      18.2-32
# Name: CodeSection, Length: 2106, dtype: object

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## TODOs
# * can't just drop 0 length sentences
# * recidivism
# * separate out jail
# * total population (2019/2020 by month)

# %%
# We're currently missing a bunch of data that doesn't fall into any category, so we need to scale up counts 
# by the ratio of actual total data to the data we're catching
scale_factor = len(sdc_data) / len(sdc_data[sdc_data.crime_type.notnull()])
sorted_data = sdc_data[sdc_data.crime_type.notnull()]

# Calculate LOS using our percentage served data
sorted_data['LOS'] = sorted_data.apply(lambda x: LOS_BY_CRIME[x.crime_type] * x.total_sentence_months, axis=1)

# Drop sentences that will round to 0
sorted_data = sorted_data[sorted_data.LOS > 0.5]

# Calculate time_step column
sorted_data['time_step'] = (sorted_data.year - 2019) * 12 + sorted_data.month

# Create outflows table
outflows_data = sorted_data.groupby(['time_step', 'tier']).count()[['Address']].reset_index().rename(
    {'Address': 'total_population'}, axis=1
)
outflows_data['compartment'] = 'pretrial'
outflows_data['outflow_to'] = 'prison'
outflows_data.total_population *= scale_factor
outflows_data = outflows_data[(outflows_data['time_step'] > -108) & (outflows_data['time_step'] <= 33)]
outflows_data.time_step = outflows_data.time_step.astype(int)
outflows_data.total_population = outflows_data.total_population.astype(float)
outflows_data.head()
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\2152295866.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sorted_data['LOS'] = sorted_data.apply(lambda x: LOS_BY_CRIME[x.crime_type] * x.total_sentence_months, axis=1)
#       time_step  tier  total_population compartment outflow_to
# 1229       -107     0        131.538353    pretrial     prison
# 1230       -107     2        166.504245    pretrial     prison
# 1231       -107     3        114.887929    pretrial     prison
# 1232       -107     4       1638.401770    pretrial     prison
# 1233       -106     0        121.548099    pretrial     prison

# %%
tiers = range(outflows_data['tier'].max() + 1)

# Create transitions datta
transitions_data = sorted_data.copy()
transitions_data['compartment_duration'] = transitions_data.LOS.round()
transitions_data = transitions_data.groupby([
    'compartment_duration', 'tier'
]).count()[['Address']].reset_index().rename({'Address': 'total_population'}, axis=1)
transitions_data['compartment'] = 'prison'
transitions_data['outflow_to'] = 'release'

# Leaving out recidivism for now because we don't have stats by tier

# add release transitions as well

# # taken from here (https://vadoc.virginia.gov/media/1681/vadoc-recidivism-re-arrest-rates-report-2016.pdf)
# RECIDIVISM_BY_CRIME_TYPE = {
#     'ARSON': 0.203,
#     'ASSAULT': 0.246,
#     'BURGLARY': 0.296,
#     'CAPITAL_MURDER': 0.073,
#     'CONSPIRACY': 0.263,
#     'DRUG_OTHER': 0.212,
#     'DRUG_POSSESSION': 0.239,
#     'DRUG_SALE': 0.193,
#     'DWI': 0.184,
#     'FIRST_DEGREE_MURDER': 0.073,
#     'KIDNAPPING': 0.146,
#     'LARCENY': 0.284,
#     'MANSLAUGHTER': 0.105,
#     'OTHER_MURDER': 0.073,
#     'RAPE': 0.226,
#     'ROBBERY': 0.206,
#     'SECOND_DEGREE_MURDER': 0.073,
#     'SEX_OFFENSE': 0.25,        
#     'WEAPON': 0.209
# }

# # taken from https://vadoc.virginia.gov/media/1680/vadoc-state-recidivism-report-2021-05.pdf
# RECIDIVISM_BY_MONTHS_SINCE_RELEASE = {
#     6: (1.1 + 1.3 + 1.5 + 1.3  + 1.3 + 1.2) / 6,
#     12: (4.3 + 5 + 4.9 + 5 + 4.9 + 4.6) / 6,
#     18: (9.6 + 10.1 + 9.9 + 10.1 + 9.8) / 5,
#     24: (15.0 + 15.3 + 15.0 + 15.6) / 4,
#     36: (22.4 + 23.4 + 23.1 + 23.9) / 4
# }
# recidivism_transitions = pd.DataFrame({
#     'compartment': ['release'] * 36,
#     'outflow_to': ['prison'] * 36,
#     'compartment_duration': range(1, 37),
#     'total_population': (
#         [RECIDIVISM_BY_MONTHS_SINCE_RELEASE[6] / 6] * 6 + 
#         [RECIDIVISM_BY_MONTHS_SINCE_RELEASE[12] / 6] * 6 +
#         [RECIDIVISM_BY_MONTHS_SINCE_RELEASE[18] / 6] * 6 + 
#         [RECIDIVISM_BY_MONTHS_SINCE_RELEASE[24] / 6] * 6 + 
#         [RECIDIVISM_BY_MONTHS_SINCE_RELEASE[36] / 12] * 12
#     )
# })

# for crime in crime_types:
#     crime_recidivism = recidivism_transitions.copy()
#     total_recidivism = sum(RECIDIVISM_BY_MONTHS_SINCE_RELEASE.values())
#     crime_specific_total_recidivism = RECIDIVISM_BY_CRIME_TYPE[crime]
#     crime_recidivism.total_population *= crime_specific_total_recidivism / total_recidivism
#     crime_recidivism = crime_recidivism.append({
#         'compartment_duration': 36,
#         'total_population': 1 - crime_specific_total_recidivism,
#         'compartment': 'release',
#         'outflow_to': 'release_full',
#     }, ignore_index=True)
#     crime_recidivism['crime_type'] = crime
    
#     transitions_data = transitions_data.append(crime_recidivism)
    
#     # adjust outflows so we're not double counting recidivism
#     outflows_data.loc[
#         outflows_data.crime_type == crime, 'total_population'
#     ] /= 1 + crime_specific_total_recidivism


transitions_data = transitions_data.append(pd.DataFrame({
    'compartment_duration': [24] * len(tiers),
    'total_population': [1] * len(tiers),
    'compartment': ['release_full'] * len(tiers),
    'outflow_to': ['release_full'] * len(tiers),
    'tier': list(tiers),
}), ignore_index=True)

transitions_data.total_population = transitions_data.total_population.astype(float)
transitions_data.head()
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3278120145.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   transitions_data = transitions_data.append(pd.DataFrame({
#    compartment_duration  tier  total_population compartment outflow_to
# 0                   1.0     0           12404.0      prison    release
# 1                   1.0     2            2336.0      prison    release
# 2                   1.0     3            1308.0      prison    release
# 3                   1.0     4           23935.0      prison    release
# 4                   2.0     0            3701.0      prison    release

# %%
#Create alternate transitions table for policy scenario

# This estimates resentencing frequency/outcomes using the parole set-off system used in Texas
# see https://www.secondlooktexas.org/action
GRANT_RATE = 3 / (32 + 3)

# We don't have data on the distribution of set-off times after each hearing, so doing every other year
SETOFF_TIME = 24
alternate_transitions_data = pd.DataFrame()

# Tiers set by crime type -- tier 0 is not included because it means ineligible
TIERS = transitions_data.loc[transitions_data['tier'] > 0, 'tier'].unique()
# Months of sentence that must be served to be eligible for Second Look
TIER_SENTENCE_LENGTHS = [30 * 12, 25 * 12, 20 * 12, 15 * 12]

for tier in TIERS:
    eligible_data = transitions_data[
        (transitions_data['compartment'] == 'prison')
        & (transitions_data['tier'] == tier)
    ].copy()

    if eligible_data.size > 0:    
        for i in range(TIER_SENTENCE_LENGTHS[tier - 1], int(eligible_data.compartment_duration.max()), SETOFF_TIME):
            rate = GRANT_RATE
            
            # calculate population that still hasn't been released by now
            remaining_population = eligible_data.loc[
                eligible_data['compartment_duration'] > i, 'total_population'
            ].sum()
            
            # reduce the population size of people staying in prison longer than this by the number of people being
            # released via resentencing right now
            eligible_data.loc[eligible_data['compartment_duration'] > i, 'total_population'] *= 1 - rate
            
            # add in rows of data for the people being released right now via resentencing
            eligible_data = eligible_data.append({
                'compartment_duration': i,
                'total_population': rate*remaining_population,
                'tier': tier,
                'compartment': 'prison',
                'outflow_to': 'release'
            }, ignore_index=True)
            
        eligible_data = eligible_data.groupby([
            'compartment', 'compartment_duration', 'tier', 'outflow_to'
        ], as_index=False).sum()
        
        # The model breaks if the maximum LOS gets shorter in the new data, so if that's the case, then change it
        # so the last line of data has a tiny tiny population
        eligible_data.loc[max(eligible_data.index), 'total_population'] = max(eligible_data.loc[max(eligible_data.index), 'total_population'], 10**(-5))
        
        # append our work to the new transitions_data we're building
        alternate_transitions_data = alternate_transitions_data.append(eligible_data)

# Round population numbers to avoid tiny populations in weird places
alternate_transitions_data.total_population = alternate_transitions_data.total_population.apply(lambda x: round(x, 5))
# drop the rows that are now rounded to zero
alternate_transitions_data = alternate_transitions_data[alternate_transitions_data.total_population > 0]
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# C:\Users\isaac\AppData\Local\Temp\ipykernel_28528\3139668628.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eligible_data = eligible_data.append({
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 44
#      35     # add in rows of data for the people being released right now via resentencing
#      36     eligible_data = eligible_data.append({
#      37         'compartment_duration': i,
#      38         'total_population': rate*remaining_population,
#    (...)
#      41         'outflow_to': 'release'
#      42     }, ignore_index=True)
# ---> 44 eligible_data = eligible_data.groupby([
#      45     'compartment', 'compartment_duration', 'crime_type', 'outflow_to'
#      46 ], as_index=False).sum()
#      48 # The model breaks if the maximum LOS gets shorter in the new data, so if that's the case, then change it
#      49 # so the last line of data has a tiny tiny population
#      50 eligible_data.loc[max(eligible_data.index), 'total_population'] = max(eligible_data.loc[max(eligible_data.index), 'total_population'], 10**(-5))
#
# File ~\.virtualenvs\sdc-data-science-iCMpQ41f\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\.virtualenvs\sdc-data-science-iCMpQ41f\lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\.virtualenvs\sdc-data-science-iCMpQ41f\lib\site-packages\pandas\core\groupby\grouper.py:888, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886         in_axis, level, gpr = False, gpr, None
#     887     else:
# --> 888         raise KeyError(gpr)
#     889 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890     # Add key to exclusions
#     891     exclusions.add(gpr.key)
#
# KeyError: 'crime_type'

# %%
alternate_transitions_data.tier.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28528\930365054.py in ?()
# ----> 1 alternate_transitions_data.tier.unique()
#
# ~\.virtualenvs\sdc-data-science-iCMpQ41f\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tier'

# %%
TIER = 2
alt_data = alternate_transitions_data[alternate_transitions_data['tier'] == TIER]
og_data = transitions_data[(transitions_data['tier'] == TIER) & (transitions_data.compartment == 'prison')]
alt_data.index = alt_data.compartment_duration
og_data.index = og_data.compartment_duration

display_df = pd.DataFrame()
display_df['og'] = og_data.total_population
display_df['alternate'] = alt_data.total_population

display_df
# Out:
#                           og  alternate
# compartment_duration
# 1.0                   2336.0        NaN
# 2.0                   2050.0        NaN
# 3.0                   1221.0        NaN
# 4.0                    440.0        NaN
# 5.0                   2040.0        NaN
# 6.0                    853.0        NaN
# 7.0                    329.0        NaN
# 8.0                    337.0        NaN
# 9.0                    298.0        NaN
# 10.0                   132.0        NaN
# 11.0                  3519.0        NaN
# 12.0                    59.0        NaN
# 13.0                   110.0        NaN
# 14.0                   216.0        NaN
# 15.0                    33.0        NaN
# 16.0                   517.0        NaN
# 17.0                    37.0        NaN
# 18.0                    78.0        NaN
# 19.0                    82.0        NaN
# 20.0                    98.0        NaN
# 21.0                    33.0        NaN
# 22.0                  6929.0        NaN
# 23.0                    41.0        NaN
# 24.0                    92.0        NaN
# 25.0                    37.0        NaN
# 26.0                    25.0        NaN
# 27.0                   378.0        NaN
# 28.0                    11.0        NaN
# 29.0                    28.0        NaN
# 30.0                    41.0        NaN
# 31.0                    17.0        NaN
# 32.0                    19.0        NaN
# 33.0                  1357.0        NaN
# 34.0                    14.0        NaN
# 35.0                    21.0        NaN
# 36.0                    47.0        NaN
# 37.0                    15.0        NaN
# 38.0                   157.0        NaN
# 39.0                     3.0        NaN
# 40.0                    15.0        NaN
# 41.0                    17.0        NaN
# 42.0                     8.0        NaN
# 43.0                   549.0        NaN
# 44.0                    15.0        NaN
# 45.0                    18.0        NaN
# 46.0                    11.0        NaN
# 47.0                     8.0        NaN
# 48.0                    13.0        NaN
# 49.0                    55.0        NaN
# 50.0                    10.0        NaN
# 51.0                    12.0        NaN
# 52.0                    10.0        NaN
# 53.0                     8.0        NaN
# 54.0                  4372.0        NaN
# 55.0                    10.0        NaN
# 56.0                     7.0        NaN
# 57.0                     2.0        NaN
# 58.0                     3.0        NaN
# 59.0                     5.0        NaN
# 60.0                    32.0        NaN
# 61.0                     1.0        NaN
# 62.0                     3.0        NaN
# 63.0                     7.0        NaN
# 65.0                   295.0        NaN
# 66.0                     4.0        NaN
# 67.0                     1.0        NaN
# 68.0                     6.0        NaN
# 69.0                     5.0        NaN
# 70.0                     2.0        NaN
# 71.0                    23.0        NaN
# 72.0                     8.0        NaN
# 73.0                     7.0        NaN
# 74.0                     7.0        NaN
# 75.0                    12.0        NaN
# 76.0                   293.0        NaN
# 77.0                     3.0        NaN
# 78.0                    20.0        NaN
# 79.0                     1.0        NaN
# 80.0                     4.0        NaN
# 81.0                     4.0        NaN
# 82.0                    36.0        NaN
# 83.0                     1.0        NaN
# 84.0                     1.0        NaN
# 85.0                     1.0        NaN
# 86.0                    12.0        NaN
# 87.0                   302.0        NaN
# 88.0                     1.0        NaN
# 89.0                     2.0        NaN
# 90.0                     1.0        NaN
# 91.0                     1.0        NaN
# 92.0                    18.0        NaN
# 93.0                     1.0        NaN
# 94.0                     1.0        NaN
# 95.0                     2.0        NaN
# 97.0                     3.0        NaN
# 98.0                   100.0        NaN
# 99.0                     1.0        NaN
# 100.0                    2.0        NaN
# 101.0                    9.0        NaN
# 102.0                    2.0        NaN
# 103.0                    6.0        NaN
# 104.0                    2.0        NaN
# 105.0                    2.0        NaN
# 106.0                    3.0        NaN
# 107.0                    1.0        NaN
# 108.0                   32.0        NaN
# 109.0                  926.0        NaN
# 110.0                    1.0        NaN
# 111.0                    4.0        NaN
# 113.0                    1.0        NaN
# 114.0                    3.0        NaN
# 115.0                    2.0        NaN
# 116.0                    1.0        NaN
# 117.0                    1.0        NaN
# 118.0                    1.0        NaN
# 119.0                    3.0        NaN
# 120.0                   45.0        NaN
# 122.0                    1.0        NaN
# 123.0                    2.0        NaN
# 124.0                    2.0        NaN
# 125.0                    3.0        NaN
# 127.0                    2.0        NaN
# 129.0                   14.0        NaN
# 130.0                  190.0        NaN
# 131.0                    3.0        NaN
# 134.0                    2.0        NaN
# 135.0                    1.0        NaN
# 136.0                   14.0        NaN
# 137.0                    3.0        NaN
# 138.0                    2.0        NaN
# 139.0                    1.0        NaN
# 140.0                    7.0        NaN
# 141.0                   53.0        NaN
# 142.0                    1.0        NaN
# 145.0                    1.0        NaN
# 146.0                    1.0        NaN
# 147.0                    3.0        NaN
# 149.0                    3.0        NaN
# 151.0                    4.0        NaN
# 152.0                   41.0        NaN
# 153.0                    1.0        NaN
# 155.0                    1.0        NaN
# 158.0                    2.0        NaN
# 159.0                    3.0        NaN
# 162.0                    8.0        NaN
# 163.0                  308.0        NaN
# 165.0                    1.0        NaN
# 168.0                    3.0        NaN
# 169.0                    2.0        NaN
# 172.0                    2.0        NaN
# 174.0                   24.0        NaN
# 178.0                    1.0        NaN
# 180.0                    1.0        NaN
# 181.0                    1.0        NaN
# 183.0                    1.0        NaN
# 185.0                   27.0        NaN
# 190.0                    2.0        NaN
# 191.0                    2.0        NaN
# 192.0                    1.0        NaN
# 193.0                    1.0        NaN
# 194.0                    4.0        NaN
# 195.0                    3.0        NaN
# 196.0                   43.0        NaN
# 198.0                    1.0        NaN
# 206.0                    2.0        NaN
# 207.0                   17.0        NaN
# 209.0                    2.0        NaN
# 210.0                    1.0        NaN
# 214.0                    1.0        NaN
# 215.0                    1.0        NaN
# 216.0                   38.0        NaN
# 217.0                  406.0        NaN
# 218.0                   11.0        NaN
# 219.0                    2.0        NaN
# 226.0                    1.0        NaN
# 228.0                    4.0        NaN
# 229.0                    1.0        NaN
# 233.0                    1.0        NaN
# 237.0                    2.0        NaN
# 239.0                    8.0        NaN
# 240.0                    2.0        NaN
# 242.0                    1.0        NaN
# 248.0                    3.0        NaN
# 250.0                   13.0        NaN
# 253.0                    1.0        NaN
# 255.0                    1.0        NaN
# 256.0                    1.0        NaN
# 261.0                   10.0        NaN
# 266.0                    1.0        NaN
# 269.0                   19.0        NaN
# 272.0                  150.0        NaN
# 275.0                    1.0        NaN
# 283.0                    4.0        NaN
# 291.0                    1.0        NaN
# 293.0                    1.0        NaN
# 294.0                    4.0        NaN
# 300.0                    1.0        NaN
# 302.0                    3.0        NaN
# 303.0                    1.0        NaN
# 304.0                   10.0        NaN
# 309.0                    1.0        NaN
# 311.0                    1.0        NaN
# 313.0                    3.0        NaN
# 315.0                    1.0        NaN
# 322.0                    1.0        NaN
# 323.0                   10.0        NaN
# 326.0                  115.0        NaN
# 327.0                    5.0        NaN
# 337.0                    3.0        NaN
# 345.0                    3.0        NaN
# 348.0                    1.0        NaN
# 349.0                    1.0        NaN
# 359.0                    5.0        NaN
# 364.0                    1.0        NaN
# 370.0                    3.0        NaN
# 377.0                    6.0        NaN
# 381.0                   34.0        NaN
# 391.0                    3.0        NaN
# 399.0                    3.0        NaN
# 402.0                    2.0        NaN
# 404.0                    1.0        NaN
# 408.0                    1.0        NaN
# 409.0                    1.0        NaN
# 413.0                    2.0        NaN
# 431.0                   12.0        NaN
# 434.0                    2.0        NaN
# 435.0                   64.0        NaN
# 436.0                    6.0        NaN
# 439.0                    2.0        NaN
# 453.0                    2.0        NaN
# 457.0                    2.0        NaN
# 478.0                    1.0        NaN
# 485.0                    3.0        NaN
# 489.0                   15.0        NaN
# 490.0                    2.0        NaN
# 506.0                    1.0        NaN
# 512.0                    1.0        NaN
# 517.0                    1.0        NaN
# 522.0                    1.0        NaN
# 533.0                    2.0        NaN
# 534.0                    1.0        NaN
# 539.0                    7.0        NaN
# 544.0                   53.0        NaN
# 545.0                    3.0        NaN
# 573.0                    1.0        NaN
# 577.0                    1.0        NaN
# 598.0                    1.0        NaN
# 609.0                    1.0        NaN
# 614.0                    1.0        NaN
# 647.0                    2.0        NaN
# 652.0                   10.0        NaN
# 707.0                    3.0        NaN
# 754.0                    1.0        NaN
# 761.0                    2.0        NaN
# 815.0                    3.0        NaN
# 854.0                    1.0        NaN
# 1015.0                   1.0        NaN
# 1023.0                   1.0        NaN
# 1067.0                  32.0        NaN
# 1076.0                  42.0        NaN
# 1078.0                   1.0        NaN
# 1079.0                   6.0        NaN
# 1088.0                   1.0        NaN
# 1090.0                   1.0        NaN

# %%
admissions_data = outflows_data.rename(
    {'total_population':'cohort_population', 'outflow_to':'admission_to', 'crime_type': 'simulation_group'},
    axis=1
)
admissions_data['time_step'] = admissions_data['time_step'].astype('int64')

transitions_data = transitions_data.rename(
    {'total_population': 'cohort_portion', 'crime_type': 'simulation_group'},
    axis=1
)

alternate_transitions_data = alternate_transitions_data.rename({
    'total_population': 'cohort_portion',
    'crime_type': 'simulation_group'
}, axis=1)

# %%
# Total population data

total_pop = {
    2021: [23811, 23644, 23769, 23897, 23966, 24229, 24467, 24625, 24694, 24738],
    2020: [29223, 29208, 29136, 28595, 27871, 27294, 26749, 26190, 25659, 25156, 24731, 24235],
    2019: [29708, 29859, 29992, 30014, 30028, 29995, 30049, 29857, 29696, 29664, 29392, 29347]
}

total_population_data = pd.DataFrame({
    'time_step': range(34),
    'compartment_population': total_pop[2019] + total_pop[2020] + total_pop[2021]
})
total_population_data['compartment'] = 'prison'
total_population_data['compartment_population'] = total_population_data['compartment_population'].astype(float)

# %%
simulation_tag = "second_look_second_pass"

upload_spark_model_inputs(
    "recidiviz-staging",
    simulation_tag,
    admissions_data,
    transitions_data,
    total_population_data,
    '../state/VA/2022/policy_configurations/SLPR_model_inputs.yaml',
)
# Out:
# C:\Users\isaac\.virtualenvs\sdc-data-science-iCMpQ41f\lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]

# %% [markdown]
# # Modeling

# %%
# Don't worry about any warnings, as long as this doesn't fail you're in business
spark_sim = SuperSimulationFactory.build_super_simulation(
    '../state/VA/2022/policy_configurations/SLPR_model_inputs.yaml'
)
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|

# %%
spark_sim.simulate_baseline(['prison'])
# Out:
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# initialization time:  2741.1044878959656
# WARNING:root:pretrial Warning: lower bound hit when predicting admissions.
# simulation_time:  1404.6609995365143

# %%
spark_sim.get_arima_output_plots('baseline_projections')
# Out:
# [<Axes: title={'center': 'compartment: pretrial\nadmission_to: prison'}, xlabel='time_step'>]

# %%
def second_look(crime):
    return SparkPolicy(
        spark_compartment='prison',
        simulation_group=crime,
        alternate_transitions_data=alternate_transitions_data,
        apply_retroactive=True,
        policy_time_step=42
    )

policy_list = []
for crime in crime_types:
    policy_list.append(second_look(crime))

test_results = spark_sim.simulate_policy(policy_list, 'prison')
# Out:
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# WARNING:root:Some transitions data not fed to a compartment:
# compartment
# release_full    1.0
# Name: cohort_portion, dtype: float64
# initialization time:  1588.9437646865845
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 14
#      11 for crime in crime_types:
#      12     policy_list.append(second_look(crime))
# ---> 14 test_results = spark_sim.simulate_policy(policy_list, 'prison')
#
# File ~\Code\python\sdc-data-science\notebooks\..\super_simulation\super_simulation.py:84, in SuperSimulation.simulate_policy(self, policy_list, output_compartment)
#      81 data_inputs = self.initializer.get_data_inputs()
#      82 user_inputs = self.initializer.get_user_inputs()
# ---> 84 simulation_output = self.simulator.simulate_policy(
#      85     user_inputs,
#      86     data_inputs,
#      87     first_relevant_time_step,
#      88     policy_list,
#      89     output_compartment,
#      90 )
#      91 self.validator.reset(
#      92     self.simulator.get_population_simulations(),
#      93     {"policy_simulation": simulation_output},
#      94 )
#      96 return simulation_output.copy()
#
# File ~\Code\python\sdc-data-science\notebooks\..\super_simulation\simulator.py:88, in Simulator.simulate_policy(self, user_inputs, data_inputs, first_relevant_time_step, policy_list, output_compartment)
#      82 self._reset_pop_simulations()
#      84 self.pop_simulations["control"] = self._build_population_simulation(
#      85     user_inputs, data_inputs, [], first_relevant_time_step
#      86 )
# ---> 88 self.pop_simulations["policy"] = self._build_population_simulation(
#      89     user_inputs, data_inputs, policy_list, first_relevant_time_step
#      90 )
#      92 self.pop_simulations["policy"].simulate_policies()
#      93 self.pop_simulations["control"].simulate_policies()
#
# File ~\Code\python\sdc-data-science\notebooks\..\super_simulation\simulator.py:363, in Simulator._build_population_simulation(user_inputs, data_inputs, policy_list, first_relevant_time_step)
#     356 @staticmethod
#     357 def _build_population_simulation(
#     358     user_inputs: UserInputs,
#    (...)
#     361     first_relevant_time_step: int,
#     362 ) -> PopulationSimulation:
# --> 363     return PopulationSimulationFactory.build_population_simulation(
#     364         user_inputs=user_inputs,
#     365         policy_list=policy_list,
#     366         first_relevant_time_step=first_relevant_time_step,
#     367         data_inputs=data_inputs,
#     368     )
#
# File ~\Code\python\sdc-data-science\notebooks\..\population_simulation\population_simulation_factory.py:113, in PopulationSimulationFactory.build_population_simulation(cls, user_inputs, policy_list, first_relevant_time_step, data_inputs)
#     109     # Insert the microsim "policies" first in the policy_list so they are
#     110     # applied before other policies on the same time step
#     111     policy_list = alternate_transition_policies + policy_list
# --> 113 sub_simulations = cls._build_sub_simulations(
#     114     data_inputs,
#     115     user_inputs,
#     116     policy_list,
#     117     first_relevant_time_step,
#     118     simulation_groups,
#     119 )
#     121 # If compartment populations are initialized, the first time-step is handled in initialization
#     122 if data_inputs.should_initialize_compartment_populations:
#
# File ~\Code\python\sdc-data-science\notebooks\..\population_simulation\population_simulation_factory.py:204, in PopulationSimulationFactory._build_sub_simulations(cls, data_inputs, user_inputs, policy_list, first_relevant_time_step, sub_groups)
#     197     # Select the policies relevant to this simulation group
#     198     group_policies = SparkPolicy.get_sub_population_policies(
#     199         policy_list, simulation_group
#     200     )
#     202     sub_simulations[
#     203         simulation_group
# --> 204     ] = SubSimulationFactory.build_sub_simulation(
#     205         admissions_data=disaggregated_admissions_data,
#     206         transitions_data=disaggregated_transitions_data,
#     207         compartments_architecture=data_inputs.compartments_architecture,
#     208         user_inputs=user_inputs,
#     209         policy_list=group_policies,
#     210         first_relevant_time_step=first_relevant_time_step,
#     211         should_single_cohort_initialize_compartments=data_inputs.should_initialize_compartment_populations,
#     212         starting_cohort_sizes=start_cohort_sizes,
#     213     )
#     215 # todo: switch order
#     216 if len(unused_transitions_data) > 0:
#
# File ~\Code\python\sdc-data-science\notebooks\..\sub_simulation\sub_simulation_factory.py:49, in SubSimulationFactory.build_sub_simulation(cls, admissions_data, transitions_data, compartments_architecture, user_inputs, policy_list, first_relevant_time_step, should_single_cohort_initialize_compartments, starting_cohort_sizes)
#      35 @classmethod
#      36 def build_sub_simulation(
#      37     cls,
#    (...)
#      45     starting_cohort_sizes: pd.DataFrame,
#      46 ) -> SubSimulation:
#      47     """Build a sub_simulation."""
# ---> 49     transitions_per_compartment, shell_policies = cls._initialize_transition_tables(
#      50         transitions_data, compartments_architecture, policy_list
#      51     )
#      53     # Preprocess the historical admissions data into separate pieces per compartment
#      54     historical_admissions = cls._load_admissions_data(
#      55         compartments_architecture, admissions_data
#      56     )
#
# File ~\Code\python\sdc-data-science\notebooks\..\sub_simulation\sub_simulation_factory.py:135, in SubSimulationFactory._initialize_transition_tables(cls, transitions_data, compartments_architecture, policy_list)
#     133 # add to the dict compartment -> transition class with policies applied
#     134 if compartment in transitions_per_compartment:
# --> 135     transitions_per_compartment[compartment].initialize_transition_tables(
#     136         compartment_policies
#     137     )
#     139 # add shell policies to dict that gets passed to initialization
#     140 else:
#     141     shell_policies[compartment] = compartment_policies
#
# File ~\Code\python\sdc-data-science\notebooks\..\compartment_transitions.py:123, in CompartmentTransitions.initialize_transition_tables(self, policy_list)
#     121 # normalize all tables
#     122 for _, transition_table in self.transition_tables.items():
# --> 123     transition_table.normalize_transitions()
#
# File ~\Code\python\sdc-data-science\notebooks\..\transition_table.py:267, in TransitionTable.normalize_transitions(self)
#     263 if self.previous_tables:
#     264     before_table = self._collapse_tables(
#     265         self.previous_tables, self.policy_time_step
#     266     )
# --> 267     self.transitory_table = TransitionTable.normalized_table(
#     268         self.transitory_table, self.max_sentence, before_table=before_table
#     269     )
#     270 for time_step, table in self.tables.items():
#     271     self.tables[time_step] = TransitionTable.normalized_table(
#     272         table, self.max_sentence
#     273     )
#
# File ~\Code\python\sdc-data-science\notebooks\..\transition_table.py:240, in TransitionTable.normalized_table(table, max_sentence, before_table)
#     195 full_release_times = np.isclose(normalized_df["remaining"], 0, SIG_FIGS)
#     197 if full_release_times.sum() == 0:
#     198
#     199     # KNOWN ISSUE: presumed rounding error for valid transitions table
#    (...)
#     237     #         f"{normalized_df.iloc[-1]}"
#     238     #     )
# --> 240     raise ValueError(
#     241         f"Transition table doesn't release everyone: "
#     242         f"{normalized_df.iloc[-1]}"
#     243     )
#     245 # Make sure all transition probabilities are between 0-1
#     246 for compartment, transition_df in normalized_df.items():
#
# ValueError: Transition table doesn't release everyone: outflow_to
# release      0.0
# remaining    1.0
# Name: 1098, dtype: float64

# %%
a = alternate_transitions_data[alternate_transitions_data.crime_type == 'RAPE']
a['t'] = a.total_population.cumsum() / a.total_population.sum()
a.plot(y='t', x='compartment_duration', ylim=[0.9,None], xlim=[None, 4000])

# %%
test_results[test_results.compartment == 'prison'].apply(lambda x: x.control_total_population - x.policy_total_population, axis=1)

# %%
for crime in crime_types:
    if alternate_transitions_data[alternate_transitions_data.crime_type == crime].compartment_duration.max() < 5:
        print(alternate_transitions_data[alternate_transitions_data.crime_type == crime])

# %%
simulation_tag = 'second_look_second_pass'
spark_sim.upload_policy_simulation_results_to_bq(simulation_tag)

# %% [markdown]
# # Eligible population stats

# %%
remaining_by_sentence
