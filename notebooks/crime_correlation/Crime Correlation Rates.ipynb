# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# function to import files
def import_csv(csv):
    df = pd.read_csv(csv, header=1)
    df = df[df.columns[0:6]]
    df.columns = ["County" if x == "County / Year" else x for x in df.columns]
    df["County"] = df["County"].str.strip()
    # Slight hard-code hacks to fix spelling mistakes
    df["County"][37] = "San Francisco"
    df["County"][26] = "Monterey"
    df["County"][39] = "San Luis Obispo"
    return df

# %%
# graph district
def graph_district(df, name):
    district = df[df["County"] == name].iloc[0][1:]
    plt.plot(range(2018, 2023), district, label=name)
    plt.legend(bbox_to_anchor=(1, 1))
    plt.xticks(range(2018, 2022))

# %%
# graph buckets of counties
def graph_bucket(df, bucket):
    for district in bucket: 
        graph_district(df, district)

# %%
# Define all 10 buckets
bucket_1 = ["Los Angeles", "San Diego", "Orange", "Riverside", "San Bernardino", "Santa Clara"]
bucket_2 = ["Alameda", "Sacramento", "Contra Costa", "Fresno", "Kern", "San Francisco"]
bucket_3 = ["Ventura", "San Joaquin", "San Mateo", "Stanislaus", "Sonoma", "Tulare"]
bucket_4 = ["Solano", "Santa Barbara", "Monterey", "Placer", "San Luis Obispo", "Merced"]
bucket_5 = ["Santa Cruz", "Marin", "Yolo", "Butte", "El Dorado", "Shasta"]
bucket_6 = ["Imperial", "Madera", "Kings", "Napa", "Humboldt", "Nevada"]
bucket_7 = ["Sutter", "Mendocino", "Yuba", "Lake", "Tehama", "San Benito"]
bucket_8 = ["Tuolumne", "Calaveras", "Siskiyou", "Amador", "Lassen", "Glenn"]
bucket_9 = ["Del Norte", "Colusa", "Plumas", "Inyo", "Mariposa", "Trinity"]
bucket_10 = ["Mono", "Modoc", "Sierra", "Alpine"]
buckets = [bucket_1, bucket_2, bucket_3, bucket_4, bucket_5, bucket_6, bucket_7, bucket_8, bucket_9, bucket_10]

# %%
df = import_csv("death_counts.csv")
df
# Out:
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][37] = "San Francisco"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][26] = "Monterey"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Visualize deaths across all 10 buckets
for i in range(len(buckets)):
    graph_bucket(df, buckets[i])
    plt.title(f"OD Deaths 2018 - 2021 in Bucket {i + 1} Counties")
    plt.xlabel("Year")
    plt.ylabel("Total Deaths Per Year")
    plt.show()

# %%
death_rate_df = import_csv("death_rates.csv")
death_rate_df
# Out:
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][37] = "San Francisco"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][26] = "Monterey"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Visualize death rates across all 10 buckets
for i in range(len(buckets)):
    graph_bucket(death_rate_df, buckets[i])
    plt.title(f"OD Death Rate 2018 - 2021 in Bucket {i + 1} Counties")
    plt.xlabel("Year")
    plt.ylabel("Deaths Per 100,000 People")
    plt.savefig(f"OD Death Rates in Bucket {i + 1}", bbox_inches="tight")
    plt.show()

# %%
education = import_csv("graduation_rates.csv")
education
# Out:
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][37] = "San Francisco"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County"][26] = "Monterey"
# /var/folders/2b/1mk8fdhx1_n4721rb_xg8x4h0000gn/T/ipykernel_98208/1249753700.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(buckets)):
    graph_bucket(education, buckets[i])
    plt.title(f"High School Dropout Rates w/ DASS - Bucket {i + 1}")
    plt.xlabel("Year")
    plt.ylabel("Dropout Rate")
    plt.savefig(f"High School Dropout Rates in Bucket {i + 1}", bbox_inches="tight")
    plt.show()

# %%
crime_rates = pd.read_csv("crime_rates.csv", header=0)
crime_rates["County"] = crime_rates["County"].str.strip()
crime_rates
# Out:
#               County  2018  2019  2020  2021
# 0            Alameda   670   633   700   651
# 1             Alpine    12    13    19    19
# 2             Amador    83    66    90    88
# 3              Butte   327   283   341   350
# 4          Calaveras   187   139   146   164
# 5             Colusa    24    26    24    23
# 6       Contra Costa   300   332   298   297
# 7          Del Norte   102    84   121   132
# 8         El Dorado    239   173   219   333
# 9            Fresno    604   599   594  1216
# 10            Glenn     55    55   128    71
# 11          Humboldt   240   310   288   303
# 12         Imperial    241   211   200   166
# 13             Inyo     80    60   101    82
# 14             Kern   2423  2864  3369  3715
# 15             Kings   133   125   103   119
# 16             Lake    201   193   193   258
# 17            Lassen    57    78    70    56
# 18       Los Angeles  5790  5564  5605  5523
# 19           Madera    453   457   231   662
# ...

# %%
# graph district
def graph_district(df, name):
    district = df[df["County"] == name].iloc[0][1:]
    plt.plot(range(2018, 2022), district, label=name)
    plt.legend(bbox_to_anchor=(1, 1))
    plt.xticks(range(2018, 2022))

# graph buckets of counties
def graph_bucket_crime(df, bucket):
    for district in bucket: 
        graph_district(df, district)
        
for i in range(len(buckets)):
    graph_bucket(crime_rates, buckets[i])
    plt.title(f"Total Violent Crimes Per Year - Bucket {i + 1}")
    plt.xlabel("Year")
    plt.ylabel("Total Violent Crimes")
    plt.savefig(f"Annual Violent Crimes in Bucket {i + 1}", bbox_inches="tight")
    plt.show()
